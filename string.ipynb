# %%
a='hello'
print(a)
# Out:
# hello

# %%
a='''python is programming language.
it is case sensitive.
it has many datatypes.'''
print(a)
# Out:
# python is programming language.
# it is case sensitive.
# it has many datatypes.

# %%
a="hello world"
print(len(a))
# Out:
# 11

# %%
print(a[1])
# Out:
# e

# %%
print(a[5])

# %%
print(a[6])
# Out:
# w

# %%
print(a[7])
# Out:
# o

# %%
a="the best things in life are free!"
print("free"in a)
# Out:
# True

# %%
print("is"in a)
# Out:
# False

# %%
a="hello world"
print(a[:5])
# Out:
# hello

# %%
print(a[3:8])
# Out:
# lo wo

# %%
print(a[-5:])
# Out:
# world

# %%
a="hello world"
print(a.upper())
# Out:
# HELLO WORLD

# %% [markdown]
# #strip()

# %%
a="   hello world      "
a.strip()
# Out:
# 'hello world'

# %%
a="mayank ,mohit"
print(a.replace("m","c"))
# Out:
# cayank ,cohit

# %%
a= "hello ,world"
print(a.split(","))
print(type(a))
# Out:
# ['hello ', 'world']
# <class 'str'>

# %%
a="hello ! world"
print(a.split("!"))
# Out:
# ['hello ', ' world']

# %%
a="hello"
b="world"
c=a+""+b
print(c)
# Out:
# helloworld

# %%
age="36"
a=f"my name is john,i am {age}"
print(a)
# Out:
# my name is john,i am 36

# %%
price=88
a=f"the price is {price} dollers"
print(a)
# Out:
# the price is 88 dollers

# %% [markdown]
# #display the price with 2 decimals

# %%
price = 88
a=f"the price is {price:.2f} dollars"
print(a)
# Out:
# the price is 88.00 dollars

# %%
a= f"the price is {20*59} dpllaers"
print(a)
# Out:
# the price is 1180 dpllaers

# %% [markdown]
# #upper case the first letter in this sentence;

# %%
x= "hello, and welcome to my world."
a= x.capitalize()
print(a)
# Out:
# Hello, and welcome to my world.

# %%
a="welcome to my world"
x= a.title()
print(x)
# Out:
# Welcome To My World

# %%
a="his name is sahil,sahil is a good boy "
x=a.count("sahil")
print(x)
# Out:
# 2

# %%
a = " love apple , apples are my favaroits furits "
print(a.count("apple", 10, 24))
# Out:
# 1

# %%
a = " love apple , apples are my favaroits furits "
print(a.find('apple'))
# Out:
# -1

# %%
  a = " love apple , apples are my favaroits furits "
print(a.find('divya'))
# Out:
# -1

# %%
a = "i love apple , apples are my favaroits furits "
print(a.find("e", 5, 10))
# Out:
# 5

# %%
a = "hello , welcome to my world "
print(a.find("e", 5, 10))
# Out:
# 9

# %%
a = " love apple , apples are my favaroits furits "
print(a.index('divya'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-753349cfcbd1> in <cell line: 2>()
#       1 a = " love apple , apples are my favaroits furits "
# ----> 2 print(a.index('divya'))
#
# ValueError: substring not found

# %%
a = " love apple , apples are my favaroits furits "

print(a.find('q'))
a = " love apple , apples are my favaroits furits "
print(a.index('q'))
# Out:
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-383ed21cb3dc> in <cell line: 5>()
#       3 print(a.find('q'))
#       4 a = " love apple , apples are my favaroits furits "
# ----> 5 print(a.index('q'))
#
# ValueError: substring not found

# %%
a = ("jhon", "peter" , "vicy")
x= "#".join(a)
print(x)
# Out:
# jhon#peter#vicy

# %%
a = ("jhon", "petert" , "vicy")
x= " _ ".join(a)
print(x)
# Out:
# jhon _ petert _ vicy

# %%
a="i could eat banana all day"
x=a.partition("banana")
print(x)
# Out:
# ('i could eat ', 'banana', ' all day')
