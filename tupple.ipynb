# %% [markdown]
# 1 LIST= changable / mutable
#
#
# 2 tupple= unchangeable / inmutable

# %%
t1=(1,2,3,4,5,6,7)
print(t1)
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
t2=(1,2,3,4,5,6,7,"a","b","f")
print(t2)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 'a', 'b', 'f')

# %%
print(type(t2))
# Out:
# <class 'tuple'>

# %% [markdown]
# # for creating single elements tuple

# %%
t1=("AAFT",)
print(t1)
# Out:
# ('AAFT',)

# %%
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2= ("A","B","C","D","E","F")
print(t2[2])
# Out:
# C

# %%
print(t2[1:2])
# Out:
# ('B',)

# %%
print(t2[:4])
# Out:
# ('A', 'B', 'C', 'D')

# %%
print(t2[3:])
# Out:
# ('D', 'E', 'F')

# %%
print(t2[-5:-3])
# Out:
# ('B', 'C')

# %%
print(t2[:-3])
# Out:
# ('A', 'B', 'C')

# %%
x=("A","B","C","D","E")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
print(y)
print (type(y))
# Out:
# ['A', 'B', 'C', 'D', 'E']
# <class 'list'>

# %%
y[2]="f"
print(y)
print(type(y))
# Out:
# ['1', '2', 'f', '4', '5']
# <class 'list'>

# %%
x=tuple(y)
print(x)
print(type(x))
# Out:
# ('1', '2', 'f', '4', '5')
# <class 'tuple'>

# %%
x=("sahil","mayank","suneet","sharma")
print(type(x))
# Out:
# <class 'tuple'>

# %%
y=list(x)
print(y)
print(type(y))
y[3]="vineet"
x=tuple(y)
print(x)
print(type(x))
# Out:
# ['sahil', 'mayank', 'suneet', 'sharma']
# <class 'list'>
# ('sahil', 'mayank', 'suneet', 'vineet')
# <class 'tuple'>

# %% [markdown]
# #adding tuple to tuple

# %%
t1=(1,2,3,4,5)
t2=(6,)
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# # multiple in tuple

# %%
fruits =("apple","banana","cherry")
print(fruits*2)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
fruits =("apple","banana","cherry","banana","graps")
print(fruits.count("banana"))
# Out:
# 2
